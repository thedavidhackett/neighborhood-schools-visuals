# %%
import numpy as np

# %%
import pandas as pd

# %%
school_aged_students_by_year = pd.read_csv("school_aged_students_by_year.csv")

# %%
school_aged_students_by_year.shape
# Out:
# (20, 2)

# %%
school_aged_students_by_year.head()
# Out:
#    YEAR  TOT_POP
# 0  2000    76465
# 1  2001    73708
# 2  2002    71357
# 3  2003    69678
# 4  2004    67502

# %%
enrollment_by_year = pd.read_csv("enrollment_by_year2.csv")

# %%
enrollment_by_year.shape
# Out:
# (21, 5)

# %%
enrollment_by_year.head()
# Out:
#    YEAR  ENROLLMENT_GRADES_K_12_NEIGHBORHOOD  ENROLLMENT_GRADES_K_12_MAGNET  \
# 0  2000                                29452                          13549
# 1  2001                                29028                          12963
# 2  2002                                28428                          12192
# 3  2003                                27212                          12184
# 4  2004                                26026                          11673
#
#    ENROLLMENT_GRADES_K_12  ENROLLMENT_GRADES_K_12_CHARTER
# 0                    1263                             NaN
# 1                     607                           783.0
# 2                     770                          1256.0
# 3                     970                          2280.0
# 4                    1452                          2529.0

# %%
enrollment_vs_student_pop = enrollment_by_year.merge(school_aged_students_by_year, on="YEAR", how="left")

# %%
enrollment_vs_student_pop.head()
# Out:
#    YEAR  ENROLLMENT_GRADES_K_12_NEIGHBORHOOD  ENROLLMENT_GRADES_K_12_MAGNET  \
# 0  2000                                29452                          13549
# 1  2001                                29028                          12963
# 2  2002                                28428                          12192
# 3  2003                                27212                          12184
# 4  2004                                26026                          11673
#
#    ENROLLMENT_GRADES_K_12  ENROLLMENT_GRADES_K_12_CHARTER  TOT_POP
# 0                    1263                             NaN  76465.0
# 1                     607                           783.0  73708.0
# 2                     770                          1256.0  71357.0
# 3                     970                          2280.0  69678.0
# 4                    1452                          2529.0  67502.0

# %%
enrollment_vs_student_pop.rename(columns={"TOT_POP": "STUDENT_AGED_POP"})
# Out:
#     YEAR  ENROLLMENT_GRADES_K_12_PUBLIC  ENROLLMENT_GRADES_K_12_CHARTER  \
# 0   2000                          44264                             NaN
# 1   2001                          42598                           783.0
# 2   2002                          41390                          1256.0
# 3   2003                          40366                          2280.0
# 4   2004                          39151                          2529.0
# 5   2005                          36696                          3350.0
# 6   2006                          35041                          4514.0
# 7   2007                          31773                          5405.0
# 8   2008                          27574                          7719.0
# 9   2009                          26108                          9221.0
# 10  2010                          25045                          9579.0
# 11  2011                          23576                         10308.0
# ...

# %%
enrollment_vs_student_pop.to_csv("enrollment_vs_student_pop2.csv")

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/w2/999xw7715kj3_sqxrf0t3nb00000gn/T/ipykernel_21825/322768712.py in <module>
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# %pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 7.2 MB 4.8 MB/s eta 0:00:01     |▉                               | 184 kB 4.8 MB/s eta 0:00:02
# ...
#      |████████████████████████████████| 61 kB 785 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 2.9 MB 34.5 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/3.1.7/libexec/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
enrollment_vs_student_pop.plot()
